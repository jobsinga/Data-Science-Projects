# %%
import numpy as np
#image handling
import PIL.Image as Image
import matplotlib.pyplot as plt
import tensorflow as tf
import tensorflow_hub as hub
import datetime
import time
# for the evaluation
# %load_ext tensorboard

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
 
from sklearn.metrics import classification_report, confusion_matrix
 
# deep learning libraries
import tensorflow as tf
import keras
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import applications
from keras.models import Sequential, load_model
from keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D, Flatten, Dense, Dropout
from keras.preprocessing import image
 
import cv2
 
import warnings
warnings.filterwarnings('ignore')

# %%
classifier_model ='https://tfhub.dev/google/tf2-preview/mobilenet_v2/classification/4'   
shape = (224,224)
## wrap the model with Sequential model
classifier = tf.keras.Sequential([
    hub.KerasLayer(classifier_model, input_shape = shape + (3,))
])
# Out:
# WARNING:tensorflow:Please fix your imports. Module tensorflow.python.training.tracking.data_structures has been moved to tensorflow.python.trackable.data_structures. The old module will be deleted in version 2.11.

# %%
# folders paths
train_path = "C:/Users/WeixiLi/Desktop/Broccoli/train"
test_path = "C:/Users/WeixiLi/Desktop/Broccoli/test"

# %%
# Data agumentation and pre-processing using tensorflow
gen = ImageDataGenerator(
                  rescale=1./255.,
                  horizontal_flip = True,
                  vertical_flip = True,
                  validation_split=0.2, # training: 80% data, validation: 20% data
                  brightness_range=[0.2,1.0]
                 )
 
train_generator = gen.flow_from_directory(
    #labels, # dataframe
    #directory = 
    train_path, # images data path / folder in which images are there
    #x_col = 'id',
    #y_col = 'breed',
    subset="training",
    color_mode="rgb",
    target_size = (240,320), # image height , image width
    class_mode="categorical",
    batch_size=64,
    shuffle=True,
    seed=42,
)
 
validation_generator = gen.flow_from_directory(
    #labels, # dataframe
    #directory = 
    train_path, # images data path / folder in which images are there
    #x_col = 'id',
    #y_col = 'breed',
    subset="validation",
    color_mode="rgb",
    target_size = (240,320), # image height , image width
    class_mode="categorical",
    batch_size=64,
    shuffle=True,
    seed=42,
)
# Out:
# Found 567 images belonging to 4 classes.
# Found 141 images belonging to 4 classes.

# %%
#inputs = tf.keras.Input(shape=(240, 320, 3))
base_model = tf.keras.applications.mobilenet_v2.MobileNetV2(weights="imagenet", input_shape=(240, 320, 3), include_top=False)
base_model.trainable = False

base_learning_rate = 0.0001

flatten_layer = tf.keras.layers.Flatten()

drop_out = tf.keras.layers.Dropout(0.7)

output = tf.keras.layers.Dense(4, activation= 'softmax') 


model = tf.keras.Sequential([
  base_model,
  flatten_layer,
  drop_out,
  output
])



model.compile(optimizer= tf.keras.optimizers.Adam(learning_rate=base_learning_rate/10),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

#reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.2,
#                              patience=5)


EPOCHS = 250

history = model.fit(train_generator, epochs=EPOCHS, verbose=1, validation_data=validation_generator, #callbacks=[reduce_lr]
                   )
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Epoch 1/250
# 9/9 [==============================] - 87s 9s/step - loss: 2.9893 - accuracy: 0.2751 - val_loss: 1.4635 - val_accuracy: 0.4468
# Epoch 2/250
# 9/9 [==============================] - 71s 8s/step - loss: 2.6167 - accuracy: 0.3739 - val_loss: 1.4909 - val_accuracy: 0.4894
# Epoch 3/250
# 9/9 [==============================] - 72s 8s/step - loss: 2.2345 - accuracy: 0.4515 - val_loss: 1.5159 - val_accuracy: 0.4184
# Epoch 4/250
# 9/9 [==============================] - 84s 9s/step - loss: 2.1056 - accuracy: 0.4444 - val_loss: 1.2538 - val_accuracy: 0.4894
# Epoch 5/250
# 9/9 [==============================] - 70s 8s/step - loss: 2.3066 - accuracy: 0.4021 - val_loss: 1.0940 - val_accuracy: 0.5319
# Epoch 6/250
# 9/9 [==============================] - 70s 8s/step - loss: 2.0811 - accuracy: 0.4198 - val_loss: 1.2155 - val_accuracy: 0.4326
# Epoch 7/250
# 9/9 [==============================] - 70s 8s/step - loss: 2.0494 - accuracy: 0.4392 - val_loss: 1.0922 - val_accuracy: 0.5390
# Epoch 8/250
# 9/9 [==============================] - 81s 9s/step - loss: 1.8775 - accuracy: 0.4621 - val_loss: 1.1979 - val_accuracy: 0.5390
# Epoch 9/250
# 9/9 [==============================] - 102s 11s/step - loss: 2.1974 - accuracy: 0.4691 - val_loss: 1.1630 - val_accuracy: 0.5319
# Epoch 10/250
# 9/9 [==============================] - 81s 9s/step - loss: 2.0091 - accuracy: 0.4533 - val_loss: 1.0638 - val_accuracy: 0.5035
# Epoch 11/250
# 9/9 [==============================] - 93s 10s/step - loss: 1.8733 - accuracy: 0.4938 - val_loss: 1.1628 - val_accuracy: 0.4823
# Epoch 12/250
# 9/9 [==============================] - 72s 8s/step - loss: 1.7182 - accuracy: 0.5009 - val_loss: 1.1013 - val_accuracy: 0.5319
# Epoch 13/250
# 9/9 [==============================] - 69s 8s/step - loss: 1.6144 - accuracy: 0.5168 - val_loss: 0.9476 - val_accuracy: 0.5816
# Epoch 14/250
# 9/9 [==============================] - 69s 8s/step - loss: 1.7473 - accuracy: 0.5238 - val_loss: 0.9988 - val_accuracy: 0.5532
# Epoch 15/250
# 9/9 [==============================] - 75s 8s/step - loss: 1.7691 - accuracy: 0.5079 - val_loss: 1.0687 - val_accuracy: 0.5390
# Epoch 16/250
# 9/9 [==============================] - 74s 8s/step - loss: 1.6704 - accuracy: 0.5203 - val_loss: 1.1550 - val_accuracy: 0.5177
# Epoch 17/250
# 9/9 [==============================] - 80s 9s/step - loss: 1.6427 - accuracy: 0.5238 - val_loss: 1.1174 - val_accuracy: 0.5816
# Epoch 18/250
# 9/9 [==============================] - 88s 10s/step - loss: 1.4783 - accuracy: 0.5520 - val_loss: 1.1861 - val_accuracy: 0.5177
# Epoch 19/250
# 9/9 [==============================] - 87s 10s/step - loss: 1.5584 - accuracy: 0.5467 - val_loss: 1.1436 - val_accuracy: 0.5035
# Epoch 20/250
# 9/9 [==============================] - 75s 8s/step - loss: 1.4672 - accuracy: 0.5873 - val_loss: 1.1033 - val_accuracy: 0.5319
# Epoch 21/250
# 9/9 [==============================] - 69s 8s/step - loss: 1.3900 - accuracy: 0.5679 - val_loss: 0.9611 - val_accuracy: 0.5816
# Epoch 22/250
# 9/9 [==============================] - 70s 8s/step - loss: 1.3417 - accuracy: 0.5926 - val_loss: 0.9574 - val_accuracy: 0.5674
# Epoch 23/250
# 9/9 [==============================] - 71s 8s/step - loss: 1.3917 - accuracy: 0.5979 - val_loss: 0.9470 - val_accuracy: 0.5816
# Epoch 24/250
# 9/9 [==============================] - 70s 8s/step - loss: 1.4361 - accuracy: 0.5820 - val_loss: 1.1228 - val_accuracy: 0.5745
# Epoch 25/250
# 9/9 [==============================] - 70s 8s/step - loss: 1.5899 - accuracy: 0.5538 - val_loss: 1.0678 - val_accuracy: 0.5461
# Epoch 26/250
# 9/9 [==============================] - 70s 8s/step - loss: 1.2355 - accuracy: 0.6367 - val_loss: 1.0107 - val_accuracy: 0.5887
# Epoch 27/250
# 9/9 [==============================] - 70s 8s/step - loss: 1.4883 - accuracy: 0.5661 - val_loss: 1.1112 - val_accuracy: 0.5461
# Epoch 28/250
# 9/9 [==============================] - 70s 8s/step - loss: 1.3589 - accuracy: 0.5873 - val_loss: 0.9942 - val_accuracy: 0.5816
# Epoch 29/250
# 9/9 [==============================] - 69s 8s/step - loss: 1.3793 - accuracy: 0.5926 - val_loss: 1.0498 - val_accuracy: 0.6312
# Epoch 30/250
# 9/9 [==============================] - 69s 8s/step - loss: 1.2568 - accuracy: 0.6332 - val_loss: 1.2019 - val_accuracy: 0.5106
# Epoch 31/250
# 9/9 [==============================] - 70s 8s/step - loss: 1.2148 - accuracy: 0.6226 - val_loss: 1.0985 - val_accuracy: 0.5390
# Epoch 32/250
# 9/9 [==============================] - 69s 8s/step - loss: 1.3202 - accuracy: 0.6208 - val_loss: 1.0753 - val_accuracy: 0.5674
# Epoch 33/250
# 9/9 [==============================] - 70s 8s/step - loss: 1.3100 - accuracy: 0.5908 - val_loss: 1.0196 - val_accuracy: 0.5745
# Epoch 34/250
# 9/9 [==============================] - 69s 8s/step - loss: 1.2931 - accuracy: 0.6155 - val_loss: 0.9681 - val_accuracy: 0.6028
# Epoch 35/250
# 9/9 [==============================] - 69s 8s/step - loss: 1.0535 - accuracy: 0.6702 - val_loss: 0.9505 - val_accuracy: 0.6241
# Epoch 36/250
# 9/9 [==============================] - 70s 8s/step - loss: 1.1958 - accuracy: 0.6261 - val_loss: 1.0377 - val_accuracy: 0.5532
# Epoch 37/250
# 9/9 [==============================] - 69s 8s/step - loss: 1.1720 - accuracy: 0.6332 - val_loss: 0.9666 - val_accuracy: 0.6028
# Epoch 38/250
# 9/9 [==============================] - 69s 8s/step - loss: 1.1812 - accuracy: 0.6455 - val_loss: 1.0328 - val_accuracy: 0.5957
# Epoch 39/250
# 9/9 [==============================] - 70s 8s/step - loss: 1.1492 - accuracy: 0.6455 - val_loss: 0.9783 - val_accuracy: 0.5887
# Epoch 40/250
# 9/9 [==============================] - 70s 8s/step - loss: 0.9644 - accuracy: 0.7002 - val_loss: 0.9956 - val_accuracy: 0.6312
# Epoch 41/250
# 9/9 [==============================] - 69s 8s/step - loss: 1.1072 - accuracy: 0.6578 - val_loss: 1.0260 - val_accuracy: 0.6241
# Epoch 42/250
# 9/9 [==============================] - 69s 8s/step - loss: 1.0583 - accuracy: 0.6878 - val_loss: 0.9819 - val_accuracy: 0.6383
# Epoch 43/250
# 9/9 [==============================] - 69s 8s/step - loss: 1.1076 - accuracy: 0.6561 - val_loss: 0.9653 - val_accuracy: 0.6241
# Epoch 44/250
# 9/9 [==============================] - 69s 8s/step - loss: 0.9739 - accuracy: 0.6966 - val_loss: 1.0516 - val_accuracy: 0.6170
# Epoch 45/250
# 9/9 [==============================] - 70s 8s/step - loss: 0.9847 - accuracy: 0.7019 - val_loss: 0.9403 - val_accuracy: 0.6170
# Epoch 46/250
# 9/9 [==============================] - 70s 8s/step - loss: 0.9877 - accuracy: 0.6667 - val_loss: 1.0438 - val_accuracy: 0.6170
# Epoch 47/250
# 9/9 [==============================] - 69s 8s/step - loss: 0.8711 - accuracy: 0.7037 - val_loss: 1.0543 - val_accuracy: 0.6099
# Epoch 48/250
# 9/9 [==============================] - 70s 8s/step - loss: 0.9450 - accuracy: 0.6984 - val_loss: 1.0698 - val_accuracy: 0.5887
# Epoch 49/250
# 9/9 [==============================] - 70s 8s/step - loss: 0.9860 - accuracy: 0.6790 - val_loss: 0.9128 - val_accuracy: 0.6454
# Epoch 50/250
# 9/9 [==============================] - 69s 8s/step - loss: 0.9291 - accuracy: 0.7072 - val_loss: 0.9217 - val_accuracy: 0.5957
# Epoch 51/250
# 9/9 [==============================] - 70s 8s/step - loss: 1.1057 - accuracy: 0.6667 - val_loss: 1.0209 - val_accuracy: 0.5674
# Epoch 52/250
# 9/9 [==============================] - 71s 8s/step - loss: 0.8862 - accuracy: 0.7213 - val_loss: 0.8883 - val_accuracy: 0.6667
# Epoch 53/250
# 9/9 [==============================] - 70s 8s/step - loss: 0.9097 - accuracy: 0.6966 - val_loss: 0.9435 - val_accuracy: 0.6809
# Epoch 54/250
# 9/9 [==============================] - 70s 8s/step - loss: 1.0064 - accuracy: 0.6772 - val_loss: 0.9047 - val_accuracy: 0.6099
# Epoch 55/250
# 9/9 [==============================] - 69s 8s/step - loss: 0.9035 - accuracy: 0.7002 - val_loss: 0.9066 - val_accuracy: 0.6525
# Epoch 56/250
# 9/9 [==============================] - 69s 8s/step - loss: 0.8232 - accuracy: 0.7372 - val_loss: 0.9805 - val_accuracy: 0.6170
# Epoch 57/250
# 9/9 [==============================] - 70s 8s/step - loss: 0.8208 - accuracy: 0.7072 - val_loss: 1.0312 - val_accuracy: 0.6028
# Epoch 58/250
# 9/9 [==============================] - 69s 8s/step - loss: 0.8973 - accuracy: 0.7372 - val_loss: 0.8698 - val_accuracy: 0.6738
# Epoch 59/250
# 9/9 [==============================] - 69s 8s/step - loss: 0.8771 - accuracy: 0.7284 - val_loss: 0.9271 - val_accuracy: 0.6383
# Epoch 60/250
# 9/9 [==============================] - 70s 8s/step - loss: 0.8637 - accuracy: 0.7443 - val_loss: 0.9290 - val_accuracy: 0.6525
# Epoch 61/250
# 9/9 [==============================] - 70s 8s/step - loss: 0.7673 - accuracy: 0.7372 - val_loss: 0.9830 - val_accuracy: 0.5745
# Epoch 62/250
# 9/9 [==============================] - 70s 8s/step - loss: 0.8381 - accuracy: 0.7425 - val_loss: 0.8920 - val_accuracy: 0.6596
# Epoch 63/250
# 9/9 [==============================] - 70s 8s/step - loss: 0.8523 - accuracy: 0.7319 - val_loss: 0.9114 - val_accuracy: 0.6454
# Epoch 64/250
# 9/9 [==============================] - 69s 8s/step - loss: 0.7994 - accuracy: 0.7390 - val_loss: 0.8905 - val_accuracy: 0.6241
# Epoch 65/250
# 9/9 [==============================] - 70s 8s/step - loss: 0.8227 - accuracy: 0.7302 - val_loss: 1.1113 - val_accuracy: 0.5674
# Epoch 66/250
# 9/9 [==============================] - 69s 8s/step - loss: 0.8143 - accuracy: 0.7619 - val_loss: 0.8476 - val_accuracy: 0.6879
# Epoch 67/250
# 9/9 [==============================] - 69s 8s/step - loss: 0.7758 - accuracy: 0.7690 - val_loss: 0.9209 - val_accuracy: 0.6170
# Epoch 68/250
# 9/9 [==============================] - 69s 8s/step - loss: 0.8486 - accuracy: 0.7266 - val_loss: 0.9536 - val_accuracy: 0.6454
# Epoch 69/250
# 9/9 [==============================] - 69s 8s/step - loss: 0.7100 - accuracy: 0.7619 - val_loss: 0.9945 - val_accuracy: 0.6312
# Epoch 70/250
# 9/9 [==============================] - 69s 8s/step - loss: 0.7198 - accuracy: 0.7496 - val_loss: 1.0445 - val_accuracy: 0.5674
# Epoch 71/250
# 9/9 [==============================] - 69s 8s/step - loss: 0.7725 - accuracy: 0.7354 - val_loss: 0.9065 - val_accuracy: 0.6383
# Epoch 72/250
# 9/9 [==============================] - 69s 8s/step - loss: 0.7637 - accuracy: 0.7407 - val_loss: 1.0064 - val_accuracy: 0.6170
# Epoch 73/250
# 9/9 [==============================] - 69s 8s/step - loss: 0.8164 - accuracy: 0.7566 - val_loss: 0.9858 - val_accuracy: 0.6099
# Epoch 74/250
# 9/9 [==============================] - 69s 8s/step - loss: 0.6686 - accuracy: 0.7813 - val_loss: 0.9085 - val_accuracy: 0.6596
# Epoch 75/250
# 9/9 [==============================] - 69s 8s/step - loss: 0.7802 - accuracy: 0.7549 - val_loss: 1.1052 - val_accuracy: 0.6028
# Epoch 76/250
# 9/9 [==============================] - 69s 8s/step - loss: 0.7330 - accuracy: 0.7637 - val_loss: 1.0213 - val_accuracy: 0.6312
# Epoch 77/250
# 9/9 [==============================] - 69s 8s/step - loss: 0.7305 - accuracy: 0.7549 - val_loss: 0.9508 - val_accuracy: 0.6170
# Epoch 78/250
# 9/9 [==============================] - 69s 8s/step - loss: 0.7384 - accuracy: 0.7601 - val_loss: 0.9373 - val_accuracy: 0.6809
# Epoch 79/250
# 9/9 [==============================] - 69s 8s/step - loss: 0.7317 - accuracy: 0.7601 - val_loss: 0.7881 - val_accuracy: 0.7092
# Epoch 80/250
# 9/9 [==============================] - 70s 8s/step - loss: 0.7740 - accuracy: 0.7549 - val_loss: 0.9156 - val_accuracy: 0.7092
# Epoch 81/250
# 9/9 [==============================] - 69s 8s/step - loss: 0.6105 - accuracy: 0.7813 - val_loss: 0.9582 - val_accuracy: 0.6241
# Epoch 82/250
# 9/9 [==============================] - 69s 8s/step - loss: 0.7358 - accuracy: 0.7566 - val_loss: 0.9474 - val_accuracy: 0.6596
# Epoch 83/250
# 9/9 [==============================] - 70s 8s/step - loss: 0.7137 - accuracy: 0.7707 - val_loss: 0.9607 - val_accuracy: 0.6525
# Epoch 84/250
# 9/9 [==============================] - 69s 8s/step - loss: 0.6889 - accuracy: 0.7884 - val_loss: 0.9339 - val_accuracy: 0.6667
# Epoch 85/250
# 9/9 [==============================] - 69s 8s/step - loss: 0.7012 - accuracy: 0.7619 - val_loss: 0.9215 - val_accuracy: 0.6312
# Epoch 86/250
# 9/9 [==============================] - 69s 8s/step - loss: 0.5457 - accuracy: 0.7813 - val_loss: 0.9442 - val_accuracy: 0.6241
# Epoch 87/250
# 9/9 [==============================] - 70s 8s/step - loss: 0.5936 - accuracy: 0.8113 - val_loss: 1.0103 - val_accuracy: 0.6170
# Epoch 88/250
# 9/9 [==============================] - 70s 8s/step - loss: 0.6555 - accuracy: 0.7601 - val_loss: 0.9922 - val_accuracy: 0.6596
# Epoch 89/250
# 9/9 [==============================] - 70s 8s/step - loss: 0.6149 - accuracy: 0.7848 - val_loss: 0.9956 - val_accuracy: 0.6454
# Epoch 90/250
# 9/9 [==============================] - 69s 8s/step - loss: 0.6622 - accuracy: 0.7813 - val_loss: 0.9122 - val_accuracy: 0.6454
# Epoch 91/250
# 9/9 [==============================] - 69s 8s/step - loss: 0.6102 - accuracy: 0.8042 - val_loss: 0.9681 - val_accuracy: 0.6383
# Epoch 92/250
# 9/9 [==============================] - 70s 8s/step - loss: 0.6109 - accuracy: 0.8007 - val_loss: 1.0621 - val_accuracy: 0.6170
# Epoch 93/250
# 9/9 [==============================] - 70s 8s/step - loss: 0.6408 - accuracy: 0.7989 - val_loss: 1.0222 - val_accuracy: 0.6028
# Epoch 94/250
# 9/9 [==============================] - 69s 8s/step - loss: 0.6040 - accuracy: 0.8007 - val_loss: 1.0477 - val_accuracy: 0.6170
# Epoch 95/250
# 9/9 [==============================] - 70s 8s/step - loss: 0.6272 - accuracy: 0.8025 - val_loss: 0.9088 - val_accuracy: 0.6950
# Epoch 96/250
# 9/9 [==============================] - 70s 8s/step - loss: 0.6617 - accuracy: 0.7725 - val_loss: 0.9605 - val_accuracy: 0.6596
# Epoch 97/250
# 9/9 [==============================] - 69s 8s/step - loss: 0.5583 - accuracy: 0.7848 - val_loss: 0.8979 - val_accuracy: 0.6667
# Epoch 98/250
# 9/9 [==============================] - 69s 8s/step - loss: 0.5733 - accuracy: 0.8307 - val_loss: 0.8367 - val_accuracy: 0.6596
# Epoch 99/250
# 9/9 [==============================] - 69s 8s/step - loss: 0.6236 - accuracy: 0.7919 - val_loss: 0.8411 - val_accuracy: 0.6667
# Epoch 100/250
# 9/9 [==============================] - 69s 8s/step - loss: 0.5513 - accuracy: 0.8219 - val_loss: 1.0304 - val_accuracy: 0.6667
# Epoch 101/250
# 9/9 [==============================] - 70s 8s/step - loss: 0.5229 - accuracy: 0.8113 - val_loss: 0.9295 - val_accuracy: 0.6383
# Epoch 102/250
# 9/9 [==============================] - 70s 8s/step - loss: 0.5715 - accuracy: 0.8219 - val_loss: 0.9226 - val_accuracy: 0.6879
# Epoch 103/250
# 9/9 [==============================] - 70s 8s/step - loss: 0.4805 - accuracy: 0.8219 - val_loss: 0.9905 - val_accuracy: 0.6596
# Epoch 104/250
# 9/9 [==============================] - 70s 8s/step - loss: 0.5429 - accuracy: 0.8254 - val_loss: 0.9323 - val_accuracy: 0.6738
# Epoch 105/250
# 9/9 [==============================] - 69s 8s/step - loss: 0.5892 - accuracy: 0.7989 - val_loss: 0.9561 - val_accuracy: 0.6525
# Epoch 106/250
# 9/9 [==============================] - 70s 8s/step - loss: 0.4805 - accuracy: 0.8377 - val_loss: 0.7939 - val_accuracy: 0.6879
# Epoch 107/250
# 9/9 [==============================] - 69s 8s/step - loss: 0.5863 - accuracy: 0.8095 - val_loss: 0.9200 - val_accuracy: 0.6667
# Epoch 108/250
# 9/9 [==============================] - 69s 8s/step - loss: 0.5511 - accuracy: 0.8219 - val_loss: 0.8890 - val_accuracy: 0.6950
# Epoch 109/250
# 9/9 [==============================] - 70s 8s/step - loss: 0.5443 - accuracy: 0.8166 - val_loss: 1.0069 - val_accuracy: 0.6525
# Epoch 110/250
# 9/9 [==============================] - 70s 8s/step - loss: 0.5661 - accuracy: 0.8254 - val_loss: 0.9195 - val_accuracy: 0.6950
# Epoch 111/250
# 9/9 [==============================] - 69s 8s/step - loss: 0.5239 - accuracy: 0.8219 - val_loss: 0.8979 - val_accuracy: 0.7092
# Epoch 112/250
# 9/9 [==============================] - 69s 8s/step - loss: 0.5498 - accuracy: 0.8078 - val_loss: 0.8076 - val_accuracy: 0.7234
# Epoch 113/250
# 9/9 [==============================] - 69s 8s/step - loss: 0.5119 - accuracy: 0.8395 - val_loss: 0.9909 - val_accuracy: 0.6525
# Epoch 114/250
# 9/9 [==============================] - 69s 8s/step - loss: 0.4949 - accuracy: 0.8342 - val_loss: 0.8918 - val_accuracy: 0.6950
# Epoch 115/250
# 9/9 [==============================] - 70s 8s/step - loss: 0.4937 - accuracy: 0.8236 - val_loss: 0.9031 - val_accuracy: 0.6170
# Epoch 116/250
# 9/9 [==============================] - 69s 8s/step - loss: 0.5241 - accuracy: 0.8342 - val_loss: 0.9603 - val_accuracy: 0.6738
# Epoch 117/250
# 9/9 [==============================] - 69s 8s/step - loss: 0.5346 - accuracy: 0.8307 - val_loss: 0.8541 - val_accuracy: 0.7163
# Epoch 118/250
# 9/9 [==============================] - 69s 8s/step - loss: 0.4107 - accuracy: 0.8483 - val_loss: 0.9134 - val_accuracy: 0.6667
# Epoch 119/250
# 9/9 [==============================] - 70s 8s/step - loss: 0.4540 - accuracy: 0.8377 - val_loss: 0.9437 - val_accuracy: 0.6879
# Epoch 120/250
# 9/9 [==============================] - 69s 8s/step - loss: 0.5418 - accuracy: 0.8236 - val_loss: 0.8481 - val_accuracy: 0.6950
# Epoch 121/250
# 9/9 [==============================] - 70s 8s/step - loss: 0.4815 - accuracy: 0.8360 - val_loss: 0.8592 - val_accuracy: 0.6950
# Epoch 122/250
# 9/9 [==============================] - 70s 8s/step - loss: 0.5107 - accuracy: 0.8307 - val_loss: 0.9506 - val_accuracy: 0.6950
# Epoch 123/250
# 9/9 [==============================] - 69s 8s/step - loss: 0.4348 - accuracy: 0.8501 - val_loss: 1.1331 - val_accuracy: 0.6241
# Epoch 124/250
# 9/9 [==============================] - 70s 8s/step - loss: 0.4481 - accuracy: 0.8219 - val_loss: 1.0920 - val_accuracy: 0.6809
# Epoch 125/250
# 9/9 [==============================] - 69s 8s/step - loss: 0.4370 - accuracy: 0.8483 - val_loss: 1.0644 - val_accuracy: 0.6667
# Epoch 126/250
# 9/9 [==============================] - 69s 8s/step - loss: 0.4337 - accuracy: 0.8307 - val_loss: 1.0127 - val_accuracy: 0.6596
# Epoch 127/250
# 9/9 [==============================] - 70s 8s/step - loss: 0.4248 - accuracy: 0.8483 - val_loss: 0.9832 - val_accuracy: 0.7021
# Epoch 128/250
# 9/9 [==============================] - 1427s 178s/step - loss: 0.4278 - accuracy: 0.8554 - val_loss: 0.9489 - val_accuracy: 0.6596
# Epoch 129/250
# 9/9 [==============================] - 73s 8s/step - loss: 0.4101 - accuracy: 0.8607 - val_loss: 0.9071 - val_accuracy: 0.6809
# Epoch 130/250
# 9/9 [==============================] - 70s 8s/step - loss: 0.4663 - accuracy: 0.8554 - val_loss: 0.9702 - val_accuracy: 0.6312
# Epoch 131/250
# 9/9 [==============================] - 70s 8s/step - loss: 0.4067 - accuracy: 0.8607 - val_loss: 0.8706 - val_accuracy: 0.6738
# Epoch 132/250
# 9/9 [==============================] - 71s 8s/step - loss: 0.4857 - accuracy: 0.8219 - val_loss: 0.9016 - val_accuracy: 0.6809
# Epoch 133/250
# 9/9 [==============================] - 70s 8s/step - loss: 0.4872 - accuracy: 0.8360 - val_loss: 0.9406 - val_accuracy: 0.6525
# Epoch 134/250
# 9/9 [==============================] - 83s 9s/step - loss: 0.4655 - accuracy: 0.8395 - val_loss: 0.9475 - val_accuracy: 0.6525
# Epoch 135/250
# 9/9 [==============================] - 87s 10s/step - loss: 0.4455 - accuracy: 0.8307 - val_loss: 0.8702 - val_accuracy: 0.6454
# Epoch 136/250
# 9/9 [==============================] - 83s 9s/step - loss: 0.5143 - accuracy: 0.8342 - val_loss: 0.9408 - val_accuracy: 0.6667
# Epoch 137/250
# 9/9 [==============================] - 70s 8s/step - loss: 0.4672 - accuracy: 0.8607 - val_loss: 1.0496 - val_accuracy: 0.6383
# Epoch 138/250
# 9/9 [==============================] - 70s 8s/step - loss: 0.4538 - accuracy: 0.8466 - val_loss: 0.9896 - val_accuracy: 0.6454
# Epoch 139/250
# 9/9 [==============================] - 70s 8s/step - loss: 0.4774 - accuracy: 0.8183 - val_loss: 0.9747 - val_accuracy: 0.7092
# Epoch 140/250
# 9/9 [==============================] - 79s 9s/step - loss: 0.3474 - accuracy: 0.8748 - val_loss: 0.9614 - val_accuracy: 0.6738
# Epoch 141/250
# 9/9 [==============================] - 76s 9s/step - loss: 0.5275 - accuracy: 0.8148 - val_loss: 0.9339 - val_accuracy: 0.6525
# Epoch 142/250
# 9/9 [==============================] - 72s 8s/step - loss: 0.4124 - accuracy: 0.8695 - val_loss: 1.0487 - val_accuracy: 0.6950
# Epoch 143/250
# 9/9 [==============================] - 73s 8s/step - loss: 0.3746 - accuracy: 0.8536 - val_loss: 0.9385 - val_accuracy: 0.6596
# Epoch 144/250
# 9/9 [==============================] - 83s 9s/step - loss: 0.3818 - accuracy: 0.8765 - val_loss: 0.7581 - val_accuracy: 0.7092
# Epoch 145/250
# 9/9 [==============================] - 87s 10s/step - loss: 0.3855 - accuracy: 0.8801 - val_loss: 0.9830 - val_accuracy: 0.6667
# Epoch 146/250
# 9/9 [==============================] - 79s 9s/step - loss: 0.3511 - accuracy: 0.8607 - val_loss: 0.9737 - val_accuracy: 0.6809
# Epoch 147/250
# 9/9 [==============================] - 87s 10s/step - loss: 0.3673 - accuracy: 0.8713 - val_loss: 0.9275 - val_accuracy: 0.7092
# Epoch 148/250
# 9/9 [==============================] - 74s 8s/step - loss: 0.4235 - accuracy: 0.8342 - val_loss: 0.8446 - val_accuracy: 0.6667
# Epoch 149/250
# 9/9 [==============================] - 87s 10s/step - loss: 0.3927 - accuracy: 0.8801 - val_loss: 0.8373 - val_accuracy: 0.6738
# Epoch 150/250
# 9/9 [==============================] - 85s 9s/step - loss: 0.3580 - accuracy: 0.8695 - val_loss: 1.1324 - val_accuracy: 0.6525
# Epoch 151/250
# 9/9 [==============================] - 74s 8s/step - loss: 0.3732 - accuracy: 0.8713 - val_loss: 0.8260 - val_accuracy: 0.7021
# Epoch 152/250
# 9/9 [==============================] - 93s 10s/step - loss: 0.3943 - accuracy: 0.8607 - val_loss: 1.0364 - val_accuracy: 0.6383
# Epoch 153/250
# 9/9 [==============================] - 87s 10s/step - loss: 0.3913 - accuracy: 0.8765 - val_loss: 0.8015 - val_accuracy: 0.7305
# Epoch 154/250
# 9/9 [==============================] - 76s 9s/step - loss: 0.3489 - accuracy: 0.8783 - val_loss: 0.8288 - val_accuracy: 0.6879
# Epoch 155/250
# 9/9 [==============================] - 91s 10s/step - loss: 0.3493 - accuracy: 0.8660 - val_loss: 0.9660 - val_accuracy: 0.6525
# Epoch 156/250
# 9/9 [==============================] - 91s 10s/step - loss: 0.3856 - accuracy: 0.8730 - val_loss: 0.9857 - val_accuracy: 0.6596
# Epoch 157/250
# 9/9 [==============================] - 88s 10s/step - loss: 0.4169 - accuracy: 0.8448 - val_loss: 1.0455 - val_accuracy: 0.5816
# Epoch 158/250
# 9/9 [==============================] - 88s 10s/step - loss: 0.3857 - accuracy: 0.8836 - val_loss: 0.9144 - val_accuracy: 0.6809
# Epoch 159/250
# 9/9 [==============================] - 87s 10s/step - loss: 0.4141 - accuracy: 0.8589 - val_loss: 1.0504 - val_accuracy: 0.6879
# Epoch 160/250
# 9/9 [==============================] - 86s 9s/step - loss: 0.3799 - accuracy: 0.8783 - val_loss: 0.9625 - val_accuracy: 0.6809
# Epoch 161/250
# 9/9 [==============================] - 74s 8s/step - loss: 0.3340 - accuracy: 0.8854 - val_loss: 0.8988 - val_accuracy: 0.6525
# Epoch 162/250
# 9/9 [==============================] - 74s 8s/step - loss: 0.3682 - accuracy: 0.8607 - val_loss: 0.8761 - val_accuracy: 0.6383
# Epoch 163/250
# 9/9 [==============================] - 72s 8s/step - loss: 0.3240 - accuracy: 0.8660 - val_loss: 0.9339 - val_accuracy: 0.7021
# Epoch 164/250
# 9/9 [==============================] - 72s 8s/step - loss: 0.3836 - accuracy: 0.8748 - val_loss: 1.0283 - val_accuracy: 0.6950
# Epoch 165/250
# 9/9 [==============================] - 72s 8s/step - loss: 0.3239 - accuracy: 0.8977 - val_loss: 0.8786 - val_accuracy: 0.7305
# Epoch 166/250
# 9/9 [==============================] - 77s 9s/step - loss: 0.3611 - accuracy: 0.8713 - val_loss: 0.9330 - val_accuracy: 0.6738
# Epoch 167/250
# 9/9 [==============================] - 77s 9s/step - loss: 0.3278 - accuracy: 0.8889 - val_loss: 0.9581 - val_accuracy: 0.6028
# Epoch 168/250
# 9/9 [==============================] - 71s 8s/step - loss: 0.4128 - accuracy: 0.8571 - val_loss: 0.8332 - val_accuracy: 0.7021
# Epoch 169/250
# 9/9 [==============================] - 71s 8s/step - loss: 0.3501 - accuracy: 0.8695 - val_loss: 0.9052 - val_accuracy: 0.7163
# Epoch 170/250
# 9/9 [==============================] - 72s 8s/step - loss: 0.3633 - accuracy: 0.8765 - val_loss: 0.9564 - val_accuracy: 0.7092
# Epoch 171/250
# 9/9 [==============================] - 73s 8s/step - loss: 0.3709 - accuracy: 0.8624 - val_loss: 0.8515 - val_accuracy: 0.6809
# Epoch 172/250
# 9/9 [==============================] - 71s 8s/step - loss: 0.3419 - accuracy: 0.8889 - val_loss: 0.9429 - val_accuracy: 0.6596
# Epoch 173/250
# 9/9 [==============================] - 71s 8s/step - loss: 0.3373 - accuracy: 0.8801 - val_loss: 0.9188 - val_accuracy: 0.6596
# Epoch 174/250
# 9/9 [==============================] - 71s 8s/step - loss: 0.3639 - accuracy: 0.8695 - val_loss: 0.8335 - val_accuracy: 0.7021
# Epoch 175/250
# 9/9 [==============================] - 74s 8s/step - loss: 0.2994 - accuracy: 0.8836 - val_loss: 0.7873 - val_accuracy: 0.7163
# Epoch 176/250
# 9/9 [==============================] - 72s 8s/step - loss: 0.3278 - accuracy: 0.8801 - val_loss: 0.9109 - val_accuracy: 0.6667
# Epoch 177/250
# 9/9 [==============================] - 73s 8s/step - loss: 0.3888 - accuracy: 0.8748 - val_loss: 0.9373 - val_accuracy: 0.6596
# Epoch 178/250
# 7/9 [======================>.......] - ETA: 13s - loss: 0.3409 - accuracy: 0.8952

# %%
# store results
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
 
 
# plot results
# accuracy
plt.figure(figsize=(10, 16))
plt.rcParams['figure.figsize'] = [16, 9]
plt.rcParams['font.size'] = 14
plt.rcParams['axes.grid'] = True
plt.rcParams['figure.facecolor'] = 'white'
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.title(f'\nTraining and Validation Accuracy. \nTrain Accuracy: {str(acc[-1])}\nValidation Accuracy: {str(val_acc[-1])}')

# %%
# loss
plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.title(f'Training and Validation Loss. \nTrain Loss: {str(loss[-1])}\nValidation Loss: {str(val_loss[-1])}')
plt.xlabel('epoch')
plt.tight_layout(pad=3.0)
plt.show()

# %%
accuracy_score = model.evaluate(validation_generator)
print(accuracy_score)
print("Accuracy: {:.4f}%".format(accuracy_score[1] * 100))
 
print("Loss: ",accuracy_score[0])

# %%
test_datagen = ImageDataGenerator(
                  rescale=1./255.,
                  #horizontal_flip = True,
                  #vertical_flip = True,
                  #validation_split=0.2, # training: 80% data, validation: 20% data
                  #brightness_range=[0.2,1.0]
                 )

test_generator = test_datagen.flow_from_directory(test_path,
                                                 shuffle=False,
                                                 batch_size=64,
                                                 target_size = (240, 320),
                                                 class_mode='categorical')

# %%
predictions = model.predict(test_generator)

# %%
test_loss, test_accuracy = model.evaluate(test_generator, batch_size=64)

# %%
print(f"Test Loss:     {test_loss}")
print(f"Test Accuracy: {test_accuracy}")

# %%
y_pred = np.argmax(predictions, axis=1)
y_true = test_generator.classes

# %%
labels = {value: key for key, value in train_generator.class_indices.items()}

print("Label Mappings for classes present in the training and validation datasets\n")
for key, value in labels.items():
    print(f"{key} : {value}")

# %%
cf_mtx = confusion_matrix(y_true, y_pred)

group_counts = ["{0:0.0f}".format(value) for value in cf_mtx.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in cf_mtx.flatten()/np.sum(cf_mtx)]
box_labels = [f"{v1}\n({v2})" for v1, v2 in zip(group_counts, group_percentages)]
box_labels = np.asarray(box_labels).reshape(3, 3)

plt.figure(figsize = (12, 10))
sns.heatmap(cf_mtx, xticklabels=[2,3,4], yticklabels=[2,3,4],
           cmap="YlGnBu", fmt="", annot=box_labels)
plt.xlabel('Predicted Classes')
plt.ylabel('True Classes')
plt.show()
